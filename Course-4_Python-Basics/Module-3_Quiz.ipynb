# %% [markdown]
# **Question 1.**
# Which statement correctly describes how conditional execution flows in Python when an if-else statement is followed by additional code?
# - Code following an if-else block executes regardless of the if-else outcome.
# - Code following an if-else block executes only if the else condition executes.
# - Code following an if-else block executes only if the if condition is True.
# - Code following an if-else block is part of the else statement unless explicitly intended.
#
# Answer: Option 1

# %%
x = 3
if x <= 1:
    print('hello world')
else:
    print('hello elsa')
print('hello hello world')
# Out:
# hello elsa
# hello hello world

# %% [markdown]
# **Question 2.**
# Which of the following is the true value of x after the following lines of code?
# x = 1
# x = x > 5

# %%
x = 1
x = x > 5
print(x)
# Out:
# False

# %% [markdown]
# **Question 3.**
# What is the output of the following lines of code?
# x = 5
# while x != 2:
#     print(x)
#     x = x – 1

# %%
x = 5
while x!=2:
    print(x)
    x = x - 1
# Out:
# 5
# 4
# 3

# %% [markdown]
# **Question 4.**
# What is the result of running the following lines of code?
#
# ```python
# class Points(object):
#     def __init__(self, x, y):
#             self.x = x
#             self.y = y
#     def print_point(self):
#         print('x=', self.x, ' y=', self.y)
# p1 = Points("A", "B")
# p1.print_point()
# ```

# %%
class Points(object):
    def __init__(self,x,y):
        self.x = x
        self.y = y
    def print_point(self):
        print('x=', self.x, ' y=', self.y)
p1 = Points("A","B")
p1.print_point()
# Out:
# x= A  y= B

# %% [markdown]
# **Question 5.**
# A museum curator is labeling artifacts using Python. The following code processes a list of ancient items:
#
# ```python
# items = ["Vase", "Statue", "Mask"]
# for index, item in enumerate(items, start=1):
#     print(f"Exhibit {index}: {item} - Ancient Greece")
# ```
#
# What will be displayed on the museum labels?

# %%
items = ["Vase", "Statue", "Mask"]
for index, item in enumerate(items, start=1):
    print(f"Exhibit {index}: {item} - Ancient Greece")
# Out:
# Exhibit 1: Vase - Ancient Greece
# Exhibit 2: Statue - Ancient Greece
# Exhibit 3: Mask - Ancient Greece

# %% [markdown]
# **Question 6.**
# What is the result of running the following lines of code?
#
# ```python
# class Points(object):
#     def __init__(self, x, y):
#         self.x = x
#         self.y = y
#     def print_point(self):
#         print('x=', self.x, ' y=', self.y)
# p2 = Points(1, 2)
# p2.x = 'A'
# p2.print_point()
# ```

# %%
class Points(object): 
    def __init__(self, x, y): 
        self.x = x 
        self.y = y 
    def print_point(self): 
        print('x=', self.x, ' y=', self.y) 
p2 = Points(1, 2) 
p2.x = 'A' 
p2.print_point()
# Out:
# x= A  y= 2

# %% [markdown]
# **Question 7.**
# Considering the function delta, when will the following function return a value of 1?
#
# ```python
# def delta(x):
#     if x == 0:
#         y = 1
#     else:
#         y = 0
#     return y
# ```

# %%
def delta(x): 
    if x == 0: 
        y = 1 
    else: 
        y = 0 
    return y
x = 0
delta(x)
# Out:
# 1

# %% [markdown]
# **Question 8.**
# What is the output of the following line of code?
# ```python
# a = 1
# def do(x):
#     a = 100
#     return x + a
# print(do(1))
# ```

# %%
a = 1 
def do(x): 
    a = 100 
    return x + a 
print(do(1))
# Out:
# 101

# %% [markdown]
# **Question 9.**
# Which function definition demonstrates the most efficient implementation for adding two numbers?
# - Built-in sum function with individual parameters
# - Direct return of parameter summation
# - Built-in sum function with tuple conversion
# - Intermediate variable assignment before return
#
# Answer: Option 2. Avoids unecessary variables

# %% [markdown]
# **Question 10.**
# What constitutes the primary rationale for implementing granular exception handling with explicitly typed catch blocks?
# - To enable selective code segment bypassing during execution
# - Explicit exception typing provides no operational benefit
# - To identify precise exception classification and source location
# - To ensure complete program termination upon error occurrence
#
# Answer: Option 3. tbh I just picked this option because the others seem negative... :p
