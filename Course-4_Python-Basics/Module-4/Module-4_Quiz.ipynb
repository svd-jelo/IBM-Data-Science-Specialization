# %% [markdown]
# **Question 1.**
# In a machine learning algorithm, two feature vectors are represented as NumPy arrays: a=np.array([-1,1]) and b=np.array([1,1]). What will be returned when calculating np.dot(a,b)?

# %%
import numpy as np
a=np.array([-1,1])
b=np.array([1,1])
np.dot(a,b)
# Out:
# np.int64(0)

# %% [markdown]
# **Question 2.**
# What is the first step you must check before performing matrix multiplication between two NumPy arrays A and B?
# - The number of columns in A must equal the number of rows in B.
# - The arrays must have the same shape.
# - The sum of the dimensions must be even.
# - Both arrays must be square matrices.
#
# Answer: Option 1. Matrix multiplication is defined only if the number of columns of A (mxn) is equal to the number of rows of B (nxp)

# %% [markdown]
# **Question 3.** What does the shape attribute tell you about a NumPy array?
# - It returns a tuple indicating the size of the array in each dimension.
# - It returns the memory allocated for the array.
# - It returns the total number of elements in the array.
# - It returns the data type of the array elements.

# %%
a=np.array([[-1,1,2],[1,1,4]])
a.shape
# Out:
# (2, 3)

# %% [markdown]
# **Question 4.**
# If you run the following lines of code, what values will the variable “Z” take?
#
# ```python
# X=np.array([[1,0],[0,1]])
# Y=np.array([[2,2],[2,2]])
# Z=np.dot(X,Y)
# ```

# %%
X=np.array([[1,0],[0,1]])
Y=np.array([[2,2],[2,2]])
Z=np.dot(X,Y)
Z
# Out:
# array([[2, 2],
#        [2, 2]])

# %% [markdown]
# **Question 5.**
# Given the following file content for "Example1.txt":
#
# This is line 1
#
# This is line 2
#
# This is line 3
#
# What would be the output of this code?
#
# ```python
# with open("Example1.txt","r") as file1:
#
#  FileContent=file1.readline()
#
#  print(FileContent)
# ```

# %%
with open("Example1.txt","r") as file1:
    FileContent=file1.readline()

print(FileContent)
# Out:
# This is line 1

# %% [markdown]
# **Question 6.**
# Consider the following line of code:
#
# ```python
# with open(example1,"r") as file1:
# ```
# What mode is the file object in?
#
# Answer: Read mode

# %% [markdown]
# **Question 7.**
# How can you write multiple lines to a file at once using a list?
# - Use the print() function with a file parameter
# - Convert the list to a string first
# - Use the insert() method to place lines in the file
# - Use a for loop to iterate through the list, writing each element with write()
#
# Answer: Option 4 (see sample below)
# ```python
# with open(file,'w') as writefile:
#     for item in list:
#         writefile.write(item)

# %% [markdown]
# **Question 8.**
# What is the difference between the “w” and “a” modes when opening a file?
# - “w” is for writing binary files, “a” is for writing text files
# - “w” overwrites the file while “a” adds to the end of the file
# - “w” is faster but less secure than “a”
# - “w” creates new files only, “a” modifies existing files only
#
# Answer: Option 2

# %% [markdown]
# **Question 9.**
# Using the loc method, how would you access the second row of a DataFrame's column named ”artist”?
#
# Answer:
# ```python
# df.loc[1,'artist']
# ```

# %% [markdown]
# **Question 10.**
# What function would you use to load a CSV file in Pandas?
#
# Answer:
# ```python
# pd.read_csv(path)
