# %% [markdown]
# **Question 1.**
# After executing the following lines of code, what value does x hold?
#
# x = 5
#
# x = x – 2

# %%
x=5
x=x-2
print(x)
# Out:
# 3

# %% [markdown]
# **Question 2.**
# What is the output of the following operation in Python?
#
# 2 + 3 * 4 / 2

# %%
2+3*4/2
# Out:
# 8.0

# %% [markdown]
# **Question 3.**
# What data type is represented by “3.14”?

# %%
type("3.14")
# Out:
# str

# %% [markdown]
# **Question 4.**
# What is the relationship between Boolean values and integers in Python?

# %%
int(True), int(False)
# Out:
# (1, 0)

# %% [markdown]
# **Question 5.**
# In Python, what is the output of the following operation?
#
# '5' + '6'

# %%
'5' + '6'
# Out:
# '56'

# %% [markdown]
# **Question 6.**
# A content management system needs to standardize how article titles are displayed. If a writer submits the title “data science basics” stored in the variable article_title, which method would transform it to “Data Science Basics”?

# %%
article_title = "data science basics"
article_title.title()
# Out:
# 'Data Science Basics'

# %% [markdown]
# **Question 7.**
# A data analyst is extracting information from standardized product codes like “ABC-12345-XYZ”. If the product code is stored in the variable product_code, which slicing operation would extract only the middle portion “12345”?

# %%
product_code = "ABC-12345-XYZ"
product_code[4:9]
# Out:
# '12345'

# %% [markdown]
# **Question 10.**
# A developer is creating a program that needs to display the file path C:\Users\name\Documents. Which Python string correctly represents this path?

# %%
"C:\\Users\\name\\Documents"
# Out:
# 'C:\\Users\\name\\Documents'
