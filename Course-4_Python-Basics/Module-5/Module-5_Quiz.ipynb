# %% [markdown]
# **Question 1.**
# What are the three parts of a response message?
#
# Answer: Start line, header, and body; Same as a request message but with contents (body).

# %% [markdown]
# **Question 2.**
# A data scientist is scraping a webpage containing NBA player salaries. After creating the BeautifulSoup object, what would be the next step to extract all player names stored in “h3” tags?
#
# Answer: Create a list of all h3 elements using the `.find_all()` method

# %% [markdown]
# **Question 3.**
# A programmer is extracting cryptocurrency data using the PyCoinGecko API. When receiving the response, what format conversion is needed to work with the data as a Python dictionary?
#
# Answer: Applying the `json()` method to the response object

# %% [markdown]
# **Question 4.**
# Complete the sentence. The Python library we used to plot the graphs is_____.
#
# Answer: matplotlib

# %% [markdown]
# **Question 5.**
# What is the role of the 'td' tag in HTML files?
#
# Answer: they are the cells of a given row in a table.

# %% [markdown]
# **Question 6.**
# What is the structure of a query string in a GET request URL?
#
# Answer: '?' + (set of parameter-value pairs separated by '&')

# %% [markdown]
# **Question 7.**
# What is the difference between CSV, JSON, and XML file formats?
#
# Answer: CSV comma separated values, JSON is dictionary-like, XML is a markup language (it's like a tree)

# %% [markdown]
# **Question 9.**
# A developer is creating an application that needs to retrieve data from a REST API. Which code snippet correctly sends a GET request with parameters?
#
# **(a)** import requests; payload = {'name': 'John', 'ID': '123'}; r = requests.get('https://api.example.com/data', params=payload)
#
# **(b)** import requests; r = requests.get('https://api.example.com/data?name=John&ID=123', data={'secure': True})
#
# **(c)** import requests; r = requests.get('https://api.example.com/data', json={'name': 'John', 'ID': '123'})
#
# **(d)** import requests; r = requests.post('https://api.example.com/data', headers={'name': 'John', 'ID': '123'})
#
# Answer: Option (a); the `requests.ge†()` method allows us to specify the Base URL `https://api.example.com/data` and the parameter-value pairs stored in `payload` as a dictionary.

# %% [markdown]
# **Question 10.**
# What is the first step in creating a BeautifulSoup object for web scraping?
#
# Answer. Using the `BeautifulSoup()` constructor to parse the HTML
